# %% [markdown]
# # Manage Analyzers in Your Resource

# %% [markdown]
# This notebook demo how to create a simple analyzer and manage its lifecycle.
#
# Source: https://github.com/Azure-Samples/azure-ai-content-understanding-python.git
# further expanded for training purposes

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The AzureContentUnderstandingClient is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# %%
load_dotenv(override=True, dotenv_path=find_dotenv())
# Out:
# True

# %%
logging.basicConfig(level=logging.INFO)

# %%
AZURE_AI_ENDPOINT = os.getenv("AZURE_CU_ENDPOINT_NEW")
AZURE_AI_API_VERSION = os.getenv("AZURE_CU_API_VERSION_NEW", "2025-05-01-preview")
print(f"Current Azure Content Understanding endpoint: {AZURE_AI_ENDPOINT}")
print(f"Current Azure Content Understanding API version: {AZURE_AI_API_VERSION}")
# Out:
# Current Azure Content Understanding endpoint: https://epaifhub6672084982.cognitiveservices.azure.com/
# Current Azure Content Understanding API version: 2025-05-01-preview

# %%
# only if necessary, add the parent directory to the path to use shared modules
# parent_dir = Path(Path.cwd()).parent
# sys.path.append(str(parent_dir))

# import the utility class AzureContentUnderstandingClient, which is a wrapper around the Azure Content Understanding REST API client
from python.content_understanding_client_NEW import AzureContentUnderstandingClient

# %%
credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS

# %%
# As an alternative to the DefaultAzureCredential, you can register an App in Entra ID and use it client secret
# from azure.identity import ClientSecretCredential

# credential = ClientSecretCredential(
#     tenant_id=os.getenv("TENANT_ID"), 
#     client_id=os.getenv("CLIENT_ID"), 
#     client_secret=os.getenv("CLIENT_SECRET") 
# )

# # Token provider compatibile
# def token_provider(scopes=None, **kwargs):
#     if scopes is None:
#         scopes = ["https://cognitiveservices.azure.com/.default"] # original value
#     token = credential.get_token(*scopes)
#     return token.token

# # scopes = ["https://cognitiveservices.azure.com/.default"] # original value
# # token = credential.get_token(*scopes)
# # print(token.token)

# %%
# consider running az login
client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/analyzer_management", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)


# This cell printout INFO level logs about the token acquisition process (e.g. AzCli vs ClientSecretCredential)
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.identity._internal.get_token_mixin:ClientSecretCredential.get_token succeeded
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.13.4 (Windows-11-10.0.26100-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential

# %% [markdown]
# ## Create a simple analyzer
# We first create an analyzer from a template to extract invoice fields.

# %%
import uuid

ANALYZER_TEMPLATE = "analyzer_templates_NEw/call_recording_analytics.json"
CUSTOM_ANALYZER_ID = "analyzer-management-sample-" + str(uuid.uuid4())

response = client.begin_create_analyzer(CUSTOM_ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-management-sample-b5439aca-f0a7-49ff-b504-e0750f339214 create request accepted.
# INFO:python.content_understanding_client_NEW:Request result is ready after 0.00 seconds.
# {
#   "id": "1666cdb7-63f8-4067-a705-448ddedfeb61",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "analyzer-management-sample-b5439aca-f0a7-49ff-b504-e0750f339214",
#     "description": "Sample call recording analytics",
#     "createdAt": "2025-06-14T09:01:33Z",
#     "lastModifiedAt": "2025-06-14T09:01:33Z",
#     "baseAnalyzerId": "prebuilt-callCenter",
#     "config": {
#       "locales": [
#         "en-US"
#       ],
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "method": "generate",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# }

# %% [markdown]
# ## List all analyzers created in your resource

# %% [markdown]
# After the analyzer is successfully created, we can use it to analyze our input files.

# %%
all_analyzers = client.get_all_analyzers()
print(f"Number of analyzers in your resource: {len(all_analyzers['value'])}")
# print(f"The first 3 analyzer details: {json.dumps(all_analyzers['value'][:3], indent=2)}")
print(f"The last analyzer details: {json.dumps(all_analyzers['value'][:-1], indent=2)}")
# Out:
# Number of analyzers in your resource: 22
# The last analyzer details: [
#   {
#     "analyzerId": "prebuilt-callCenter",
#     "description": "Analyze call center conversations to extract transcripts, summaries, sentiment, and more.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "PostCallAnalytics",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-audioAnalyzer",
#     "description": "Transcribe conversations and extract summaries.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "AudioAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary of the conversation."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-documentAnalyzer",
#     "description": "Extract various content and layout elements such as words, paragraphs, and tables from documents.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "name": "DocumentAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph description of the document."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-imageAnalyzer",
#     "description": "Analyze images to generate descriptions.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": false,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "ImageAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph description of the image."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-invoice",
#     "description": "Extract invoice document fields.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "name": "InvoiceAnalysis",
#       "fields": {
#         "CustomerName": {
#           "type": "string",
#           "method": "extract",
#           "description": "The full name of the customer, including the primary company name and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing."
#         },
#         "InvoiceDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "CustomerId": {
#           "type": "string",
#           "method": "extract"
#         },
#         "PurchaseOrder": {
#           "type": "string",
#           "method": "extract"
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The unique identifier of the invoice, often named 'Invoice Number'"
#         },
#         "DueDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddressRecipient": {
#           "type": "string",
#           "method": "extract",
#           "description": "The recepient of customer addresss, including the recepient and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing. Ensure that all parts related to the customer\u2019s recepient identification are included to provide complete context."
#         },
#         "BillingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit billing address of the customer."
#         },
#         "BillingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ShippingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit shipping address of the customer."
#         },
#         "ShippingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "SubTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalDiscount": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalTax": {
#           "type": "number",
#           "method": "extract"
#         },
#         "InvoiceTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "AmountDue": {
#           "type": "number",
#           "method": "extract"
#         },
#         "PreviousUnpaidBalance": {
#           "type": "number",
#           "method": "extract",
#           "description": "Explicit previously unpaid balance. Please make sure it is **unpaid**, not the total amount of the previous invoice."
#         },
#         "RemittanceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address to which the payment or remittance should be sent."
#         },
#         "RemittanceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ServiceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address where the service was provided."
#         },
#         "ServiceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the vendor"
#         },
#         "CustomerTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the customer"
#         },
#         "PaymentTerm": {
#           "type": "string",
#           "method": "extract"
#         },
#         "TaxDetails": {
#           "type": "array",
#           "method": "extract",
#           "description": "The tax details of the invoice.",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "Amount": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Rate": {
#                 "type": "number",
#                 "method": "extract"
#               }
#             }
#           }
#         },
#         "Items": {
#           "type": "array",
#           "method": "extract",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "TotalPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The total amount of the line item."
#               },
#               "Date": {
#                 "type": "date",
#                 "method": "extract"
#               },
#               "Description": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "Quantity": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "ProductCode": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Product code, product number, or SKU associated with the specific line item"
#               },
#               "TaxAmount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The tax amount of the line item."
#               },
#               "TaxRate": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Unit": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "UnitPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The net or gross price of one unit of the item"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-videoAnalyzer",
#     "description": "Analyze videos to extract transcript and description for each segment.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableFace": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "auto",
#       "disableFaceBlurring": false
#     },
#     "fieldSchema": {
#       "name": "VideoAnalysis",
#       "fields": {
#         "Segments": {
#           "type": "array",
#           "items": {
#             "type": "object",
#             "properties": {
#               "SegmentId": {
#                 "type": "string"
#               },
#               "StartTimeMs": {
#                 "type": "integer"
#               },
#               "EndTimeMs": {
#                 "type": "integer"
#               },
#               "Description": {
#                 "type": "string"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-001-build-demo-invoice",
#     "description": "",
#     "tags": {
#       "projectId": "ee114c88-f5ba-4254-a2e6-d4555f6bcdf2",
#       "templateId": "prebuilt-invoice-2025-05-01"
#     },
#     "createdAt": "2025-06-12T14:26:18Z",
#     "lastModifiedAt": "2025-06-12T14:26:18Z",
#     "baseAnalyzerId": "prebuilt-invoice",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "BillingAddressRecipient": {
#           "type": "string",
#           "method": "extract",
#           "description": "Name associated with the BillingAddress"
#         },
#         "CustomerAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Mailing address for the Customer"
#         },
#         "CustomerId": {
#           "type": "string",
#           "method": "extract",
#           "description": "Reference ID for the customer"
#         },
#         "DueDate": {
#           "type": "date",
#           "method": "extract",
#           "description": "Date payment for this invoice is due"
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "extract",
#           "description": "ID for this specific invoice (often 'Invoice Number')"
#         },
#         "PaymentTerm": {
#           "type": "string",
#           "method": "extract",
#           "description": "The terms under which the payment is meant to be paid"
#         },
#         "PurchaseOrder": {
#           "type": "string",
#           "method": "extract",
#           "description": "A purchase order reference number"
#         },
#         "RemittanceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Explicit remittance or payment address for the customer"
#         },
#         "ServiceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Explicit service address or property address for the customer"
#         },
#         "ShippingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Explicit shipping address for the customer"
#         },
#         "TotalDiscount": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total discount field identified on this invoice"
#         },
#         "TotalTax": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total tax field identified on this invoice"
#         },
#         "VendorAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Mailing address for the Vendor"
#         },
#         "VendorAddressRecipient": {
#           "type": "string",
#           "method": "extract",
#           "description": "Name associated with the VendorAddress"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract",
#           "description": "Vendor who has created this invoice"
#         },
#         "VendorTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the vendor"
#         },
#         "Items": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of line items",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "A single line item",
#             "properties": {
#               "Date": {
#                 "type": "date",
#                 "method": "extract",
#                 "description": "Date corresponding to each line item. Often it is a date the line item was shipped"
#               },
#               "ProductCode": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Product code, product number, or SKU associated with the specific line item"
#               },
#               "Description": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "The text description for the invoice line item"
#               },
#               "Quantity": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The quantity for this invoice line item"
#               },
#               "UnitPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The net price of one unit of this item"
#               },
#               "Unit": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "The unit of the line item, e.g., hours, kg, lb"
#               },
#               "TaxAmount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "Tax associated with each line item"
#               },
#               "TaxRate": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "Tax rate associated with each line item"
#               },
#               "TotalPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The total price for the line item"
#               }
#             }
#           }
#         },
#         "TaxDetails": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of tax details",
#           "items": {
#             "type": "object",
#             "description": "A single tax detail",
#             "properties": {
#               "Rate": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The rate of the tax detail"
#               },
#               "Amount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The amount of the tax detail"
#               }
#             }
#           }
#         },
#         "EmailAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": ""
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-002-my-demo-invoice",
#     "description": "",
#     "tags": {
#       "projectId": "6ff91f80-39d8-4173-90d0-8806ef0c8843",
#       "templateId": "document-2025-05-01"
#     },
#     "createdAt": "2025-06-12T14:31:19Z",
#     "lastModifiedAt": "2025-06-12T14:31:20Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "InvoiceNr": {
#           "type": "string",
#           "method": "extract",
#           "description": "The ID of the invoice"
#         },
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "The name of the company issuing the invoice"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-invoice-sample-2025-new",
#     "createdAt": "2025-06-12T16:42:30Z",
#     "lastModifiedAt": "2025-06-12T16:42:32Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "InvoiceNr": {
#           "type": "string",
#           "method": "extract",
#           "description": "The ID of the invoice"
#         },
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "The name of the company issuing the invoice"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-invoice-sample-2025",
#     "createdAt": "2025-06-12T15:47:21Z",
#     "lastModifiedAt": "2025-06-12T15:47:22Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "InvoiceNr": {
#           "type": "string",
#           "method": "extract",
#           "description": "The ID of the invoice"
#         },
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "The name of the company issuing the invoice"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-management-sample-b5439aca-f0a7-49ff-b504-e0750f339214",
#     "description": "Sample call recording analytics",
#     "createdAt": "2025-06-14T09:01:33Z",
#     "lastModifiedAt": "2025-06-14T09:01:33Z",
#     "baseAnalyzerId": "prebuilt-callCenter",
#     "config": {
#       "locales": [
#         "en-US"
#       ],
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "method": "generate",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "analyzer-prebuilt-invoice-sample-2025",
#     "createdAt": "2025-06-12T16:00:14Z",
#     "lastModifiedAt": "2025-06-12T16:00:15Z",
#     "baseAnalyzerId": "prebuilt-invoice",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "InvoiceNr": {
#           "type": "string",
#           "method": "extract",
#           "description": "The ID of the invoice"
#         },
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "The name of the company issuing the invoice"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "business-card-analyzer-lab",
#     "description": "Business card analyzer",
#     "createdAt": "2025-06-11T16:12:28Z",
#     "lastModifiedAt": "2025-06-11T16:12:29Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "fields": {
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "Company or organization"
#         },
#         "Name": {
#           "type": "string",
#           "method": "extract",
#           "description": "Contact's name"
#         },
#         "Title": {
#           "type": "string",
#           "method": "extract",
#           "description": "Contact's job title"
#         },
#         "Email": {
#           "type": "string",
#           "method": "extract",
#           "description": "Contact's email address"
#         },
#         "Phone": {
#           "type": "string",
#           "method": "extract",
#           "description": "Contact's phone number"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "business_card_analyser_procode",
#     "description": "Simple business card",
#     "createdAt": "2025-06-11T15:33:20Z",
#     "lastModifiedAt": "2025-06-11T15:33:21Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html"
#     },
#     "fieldSchema": {
#       "fields": {
#         "ContactName": {
#           "type": "string",
#           "method": "extract",
#           "description": "Name on business card"
#         },
#         "EmailAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Email address on business card"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "cu-analyzer-invoice-contract-verification",
#     "description": "",
#     "tags": {
#       "projectId": "f2521d08-02f6-4076-a814-f6a6e09edb6d",
#       "templateId": "pro-invoice-2025-05-01"
#     },
#     "createdAt": "2025-06-12T08:47:02Z",
#     "lastModifiedAt": "2025-06-12T08:47:29Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "PaymentTermsInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "ItemInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice in the goods or services sold (including detailed specifications for every line item).",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "BillingLogisticsInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice regarding billing logistics and administrative or legal issues.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "PaymentScheduleInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "TaxOrDiscountInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence regarding taxes or discounts.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "global",
#     "mode": "pro",
#     "knowledgeSources": [
#       {
#         "kind": "reference",
#         "containerUrl": "https://epaifhub3621841718.blob.core.windows.net/8f07c8d7-7c44-4807-be15-f88731f3c4cd-cu",
#         "prefix": "labelingProjects/f2521d08-02f6-4076-a814-f6a6e09edb6d/references/",
#         "fileListPath": "sources.jsonl"
#       }
#     ]
#   },
#   {
#     "analyzerId": "cu-business-card-analyzer-ui",
#     "description": "",
#     "tags": {
#       "projectId": "8c9c8733-7c2a-45e2-ae8f-745dc10adc4e",
#       "templateId": "document-2025-05-01"
#     },
#     "createdAt": "2025-06-11T15:09:26Z",
#     "lastModifiedAt": "2025-06-11T15:09:27Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "ContactName": {
#           "type": "string",
#           "method": "extract",
#           "description": "Name on business card"
#         },
#         "EmailAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Email address on business card"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "invoice-analyzer",
#     "description": "Invoice analyzer",
#     "tags": {
#       "projectId": "5658a32d-c962-4ec3-b0f9-0d1d6d3848a1",
#       "templateId": "prebuilt-invoice-2025-05-01"
#     },
#     "createdAt": "2025-06-13T15:45:49Z",
#     "lastModifiedAt": "2025-06-13T15:45:49Z",
#     "baseAnalyzerId": "prebuilt-invoice",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "fields": {
#         "AmountDue": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total amount due to the vendor"
#         },
#         "CustomerAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Mailing address for the Customer"
#         },
#         "CustomerName": {
#           "type": "string",
#           "method": "extract",
#           "description": "Customer being invoiced"
#         },
#         "InvoiceDate": {
#           "type": "date",
#           "method": "extract",
#           "description": "Date the invoice was issued"
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "extract",
#           "description": "ID for this specific invoice (often 'Invoice Number')"
#         },
#         "SubTotal": {
#           "type": "number",
#           "method": "extract",
#           "description": "Subtotal field identified on this invoice"
#         },
#         "TotalTax": {
#           "type": "number",
#           "method": "extract",
#           "description": "Total tax field identified on this invoice"
#         },
#         "VendorAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "Mailing address for the Vendor"
#         },
#         "ShippingFee": {
#           "type": "number",
#           "method": "extract",
#           "description": "Fee for shipping"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract",
#           "description": "Vendor who has created this invoice"
#         },
#         "VendorPhone": {
#           "type": "string",
#           "method": "extract",
#           "description": "Vendor telephone number"
#         },
#         "Items": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of line items",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "A single line item",
#             "properties": {
#               "ProductCode": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Product code, product number, or SKU associated with the specific line item"
#               },
#               "Description": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "The text description for the invoice line item"
#               },
#               "Quantity": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The quantity for this invoice line item"
#               },
#               "UnitPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The net price of one unit of this item"
#               },
#               "Unit": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "The unit of the line item, e.g., hours, kg, lb"
#               }
#             }
#           }
#         },
#         "TaxDetails": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of tax details",
#           "items": {
#             "type": "object",
#             "description": "A single tax detail",
#             "properties": {
#               "Rate": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The rate of the tax detail"
#               },
#               "Amount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The amount of the tax detail"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "invoice-po-matching-analyzer",
#     "description": "",
#     "tags": {
#       "projectId": "12937ff0-d687-4996-ba55-e77f78043fc7",
#       "templateId": "pro-document-2025-05-01"
#     },
#     "createdAt": "2025-06-13T14:08:15Z",
#     "lastModifiedAt": "2025-06-13T14:08:16Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "LineItems": {
#           "type": "array",
#           "method": "generate",
#           "description": "Invoice line item. It should be extracted either from invoice or PO. ",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "ItemName": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "The text description for the invoice line item"
#               },
#               "Quantity": {
#                 "type": "integer",
#                 "method": "generate",
#                 "description": "The quantity for this invoice line item"
#               },
#               "POMatch": {
#                 "type": "string",
#                 "method": "classify",
#                 "description": "Please classify the line item based on match with the PO",
#                 "enum": [
#                   "Match",
#                   "PartialMatch",
#                   "OnlyInPO"
#                 ],
#                 "enumDescriptions": {
#                   "OnlyInPO": "Line item only present in the PO but not in the invoice",
#                   "Match": "Line item matched to PO exactly",
#                   "PartialMatch": "Line item partially matched to PO, provide details in MatchingInconsistency field "
#                 }
#               },
#               "MatchingInconsistency": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Please provide explanations of the inconsistencies if POMatch is PartialMatch"
#               }
#             }
#           }
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "generate",
#           "description": ""
#         },
#         "PONumber": {
#           "type": "string",
#           "method": "generate",
#           "description": ""
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "global",
#     "mode": "pro"
#   },
#   {
#     "analyzerId": "invoice-po-wreference-files",
#     "description": "",
#     "tags": {
#       "projectId": "12b88a1e-26c0-438d-8886-33c338c80aa6",
#       "templateId": "pro-document-2025-05-01"
#     },
#     "createdAt": "2025-06-13T14:24:12Z",
#     "lastModifiedAt": "2025-06-13T14:24:37Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "LineItems": {
#           "type": "array",
#           "method": "generate",
#           "description": "Invoice line item. It should be extracted either from invoice or PO. ",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "ItemName": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "The text description for the invoice line item"
#               },
#               "Quantity": {
#                 "type": "integer",
#                 "method": "generate",
#                 "description": "The quantity for this invoice line item"
#               },
#               "POMatch": {
#                 "type": "string",
#                 "method": "classify",
#                 "description": "Please classify the line item based on match with the PO",
#                 "enum": [
#                   "Match",
#                   "PartialMatch",
#                   "OnlyInPO"
#                 ],
#                 "enumDescriptions": {
#                   "OnlyInPO": "Line item only present in the PO but not in the invoice",
#                   "Match": "Line item matched to PO exactly",
#                   "PartialMatch": "Line item partially matched to PO, provide details in MatchingInconsistency field "
#                 }
#               },
#               "MatchingInconsistency": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Please provide explanations of the inconsistencies if POMatch is PartialMatch"
#               }
#             }
#           }
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "generate",
#           "description": ""
#         },
#         "PONumber": {
#           "type": "string",
#           "method": "generate",
#           "description": ""
#         },
#         "PaymentTermsInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence.",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "global",
#     "mode": "pro",
#     "knowledgeSources": [
#       {
#         "kind": "reference",
#         "containerUrl": "https://epaifhub3621841718.blob.core.windows.net/a6b11395-ba5f-4af0-90e1-a602be23e9c5-cu",
#         "prefix": "labelingProjects/12b88a1e-26c0-438d-8886-33c338c80aa6/references/",
#         "fileListPath": "sources.jsonl"
#       }
#     ]
#   },
#   {
#     "analyzerId": "multiple-file-analyzer",
#     "description": "",
#     "tags": {
#       "projectId": "4484159f-cc01-4b9b-8623-6c920c95bcf9",
#       "templateId": "pro-invoice-2025-05-01"
#     },
#     "createdAt": "2025-06-12T09:36:45Z",
#     "lastModifiedAt": "2025-06-12T09:37:08Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "PaymentTermsInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "ItemInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice in the goods or services sold (including detailed specifications for every line item).",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "BillingLogisticsInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice regarding billing logistics and administrative or legal issues.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "PaymentScheduleInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         },
#         "TaxOrDiscountInconsistencies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List all areas of inconsistency identified in the invoice with corresponding evidence regarding taxes or discounts.",
#           "items": {
#             "type": "object",
#             "method": "generate",
#             "description": "Area of inconsistency in the invoice with the company's contracts.",
#             "properties": {
#               "Evidence": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Evidence or reasoning for the inconsistency in the invoice."
#               },
#               "InvoiceField": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Invoice field or the aspect that is inconsistent with the contract."
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "global",
#     "mode": "pro",
#     "knowledgeSources": [
#       {
#         "kind": "reference",
#         "containerUrl": "https://epaifhub3621841718.blob.core.windows.net/a6b11395-ba5f-4af0-90e1-a602be23e9c5-cu",
#         "prefix": "labelingProjects/4484159f-cc01-4b9b-8623-6c920c95bcf9/references/",
#         "fileListPath": "sources.jsonl"
#       }
#     ]
#   },
#   {
#     "analyzerId": "po-simple-analyzer",
#     "description": "",
#     "tags": {
#       "projectId": "c1a1e30e-4357-4651-a6d9-618bbd2d1fad",
#       "templateId": "document-2025-05-01"
#     },
#     "createdAt": "2025-06-13T17:15:01Z",
#     "lastModifiedAt": "2025-06-13T17:15:02Z",
#     "baseAnalyzerId": "prebuilt-documentAnalyzer",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "fields": {
#         "Company": {
#           "type": "string",
#           "method": "extract",
#           "description": "The company issuing the purchase order"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract",
#           "description": ""
#         },
#         "TotalAmount": {
#           "type": "number",
#           "method": "extract",
#           "description": "The total order amount to be paid, tax included"
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# ]

# %%
import pandas as pd
df_analyzers = pd.json_normalize(all_analyzers['value'])
df_analyzers_sorted = df_analyzers.sort_values(by='createdAt', ascending=False)
df_analyzers_sorted
# Out:
#                                            analyzerId  \
# 10  analyzer-management-sample-b5439aca-f0a7-49ff-...
# 20                                 po-simple-analyzer
# 16                                   invoice-analyzer
# 18                        invoice-po-wreference-files
# 17                       invoice-po-matching-analyzer
# 8                    analyzer-invoice-sample-2025-new
# 11              analyzer-prebuilt-invoice-sample-2025
# 9                        analyzer-invoice-sample-2025
# 7                        analyzer-002-my-demo-invoice
# 6                     analyzer-001-build-demo-invoice
# 19                             multiple-file-analyzer
# 14          cu-analyzer-invoice-contract-verification
# 12                         business-card-analyzer-lab
# 13                     business_card_analyser_procode
# 15                       cu-business-card-analyzer-ui
# 21                    singlefile-invoice-analyzer-v00
# 1                              prebuilt-audioAnalyzer
# 5                              prebuilt-videoAnalyzer
# 4                                    prebuilt-invoice
# 3                              prebuilt-imageAnalyzer
# 2                           prebuilt-documentAnalyzer
# 0                                 prebuilt-callCenter
#
#                                           description             createdAt  \
# 10                    Sample call recording analytics  2025-06-14T09:01:33Z
# 20                                                     2025-06-13T17:15:01Z
# 16                                   Invoice analyzer  2025-06-13T15:45:49Z
# 18                                                     2025-06-13T14:24:12Z
# 17                                                     2025-06-13T14:08:15Z
# 8                                                 NaN  2025-06-12T16:42:30Z
# 11                                                NaN  2025-06-12T16:00:14Z
# 9                                                 NaN  2025-06-12T15:47:21Z
# 7                                                      2025-06-12T14:31:19Z
# 6                                                      2025-06-12T14:26:18Z
# 19                                                     2025-06-12T09:36:45Z
# 14                                                     2025-06-12T08:47:02Z
# 12                             Business card analyzer  2025-06-11T16:12:28Z
# 13                               Simple business card  2025-06-11T15:33:20Z
# 15                                                     2025-06-11T15:09:26Z
# 21                                                     2025-06-11T14:35:48Z
# 1     Transcribe conversations and extract summaries.  2025-05-01T00:00:00Z
# 5   Analyze videos to extract transcript and descr...  2025-05-01T00:00:00Z
# 4                    Extract invoice document fields.  2025-05-01T00:00:00Z
# 3            Analyze images to generate descriptions.  2025-05-01T00:00:00Z
# 2   Extract various content and layout elements su...  2025-05-01T00:00:00Z
# 0   Analyze call center conversations to extract t...  2025-05-01T00:00:00Z
#
#    warnings status processingLocation      mode  config.returnDetails  \
# 10       []  ready          geography  standard                  True
# 20       []  ready          geography  standard                  True
# 16       []  ready          geography  standard                  True
# 18       []  ready             global       pro                  True
# 17       []  ready             global       pro                  True
# 8        []  ready          geography  standard                  True
# 11       []  ready          geography  standard                  True
# 9        []  ready          geography  standard                  True
# 7        []  ready          geography  standard                  True
# 6        []  ready          geography  standard                  True
# 19       []  ready             global       pro                  True
# 14       []  ready             global       pro                  True
# 12       []  ready          geography  standard                  True
# 13       []  ready          geography  standard                  True
# 15       []  ready          geography  standard                  True
# 21       []  ready          geography  standard                  True
# 1        []  ready          geography  standard                  True
# 5        []  ready          geography  standard                  True
# 4        []  ready          geography  standard                  True
# 3        []  ready          geography  standard                  True
# 2        []  ready          geography  standard                  True
# 0        []  ready          geography  standard                  True
#
#     config.disableContentFiltering   fieldSchema.name  ...  \
# 10                           False                NaN  ...
# 20                           False                NaN  ...
# 16                           False                NaN  ...
# 18                           False                NaN  ...
# 17                           False                NaN  ...
# 8                            False                NaN  ...
# 11                           False                NaN  ...
# 9                            False                NaN  ...
# 7                            False                NaN  ...
# 6                            False                NaN  ...
# 19                           False                NaN  ...
# 14                           False                NaN  ...
# 12                           False                NaN  ...
# 13                           False                NaN  ...
# 15                           False                NaN  ...
# 21                           False                NaN  ...
# 1                            False      AudioAnalysis  ...
# 5                            False      VideoAnalysis  ...
# 4                            False    InvoiceAnalysis  ...
# 3                            False      ImageAnalysis  ...
# 2                            False   DocumentAnalysis  ...
# 0                            False  PostCallAnalytics  ...
#
#    fieldSchema.fields.PONumber.type fieldSchema.fields.PONumber.method  \
# 10                              NaN                                NaN
# 20                              NaN                                NaN
# 16                              NaN                                NaN
# 18                           string                           generate
# 17                           string                           generate
# 8                               NaN                                NaN
# 11                              NaN                                NaN
# 9                               NaN                                NaN
# 7                               NaN                                NaN
# 6                               NaN                                NaN
# 19                              NaN                                NaN
# 14                              NaN                                NaN
# 12                              NaN                                NaN
# 13                              NaN                                NaN
# 15                              NaN                                NaN
# 21                              NaN                                NaN
# 1                               NaN                                NaN
# 5                               NaN                                NaN
# 4                               NaN                                NaN
# 3                               NaN                                NaN
# 2                               NaN                                NaN
# 0                               NaN                                NaN
#
#    fieldSchema.fields.PONumber.description  \
# 10                                     NaN
# 20                                     NaN
# 16                                     NaN
# 18
# 17
# 8                                      NaN
# 11                                     NaN
# 9                                      NaN
# 7                                      NaN
# 6                                      NaN
# 19                                     NaN
# 14                                     NaN
# 12                                     NaN
# 13                                     NaN
# 15                                     NaN
# 21                                     NaN
# 1                                      NaN
# 5                                      NaN
# 4                                      NaN
# 3                                      NaN
# 2                                      NaN
# 0                                      NaN
#
#    fieldSchema.fields.TotalAmount.type fieldSchema.fields.TotalAmount.method  \
# 10                                 NaN                                   NaN
# 20                              number                               extract
# 16                                 NaN                                   NaN
# 18                                 NaN                                   NaN
# 17                                 NaN                                   NaN
# 8                                  NaN                                   NaN
# 11                                 NaN                                   NaN
# 9                                  NaN                                   NaN
# 7                                  NaN                                   NaN
# 6                                  NaN                                   NaN
# 19                                 NaN                                   NaN
# 14                                 NaN                                   NaN
# 12                                 NaN                                   NaN
# 13                                 NaN                                   NaN
# 15                                 NaN                                   NaN
# 21                                 NaN                                   NaN
# 1                                  NaN                                   NaN
# 5                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 0                                  NaN                                   NaN
#
#          fieldSchema.fields.TotalAmount.description  \
# 10                                              NaN
# 20  The total order amount to be paid, tax included
# 16                                              NaN
# 18                                              NaN
# 17                                              NaN
# 8                                               NaN
# 11                                              NaN
# 9                                               NaN
# 7                                               NaN
# 6                                               NaN
# 19                                              NaN
# 14                                              NaN
# 12                                              NaN
# 13                                              NaN
# 15                                              NaN
# 21                                              NaN
# 1                                               NaN
# 5                                               NaN
# 4                                               NaN
# 3                                               NaN
# 2                                               NaN
# 0                                               NaN
#
#        fieldSchema.fields.InvoiceTotal.description  \
# 10                                             NaN
# 20                                             NaN
# 16                                             NaN
# 18                                             NaN
# 17                                             NaN
# 8                                              NaN
# 11                                             NaN
# 9                                              NaN
# 7                                              NaN
# 6                                              NaN
# 19                                             NaN
# 14                                             NaN
# 12                                             NaN
# 13                                             NaN
# 15                                             NaN
# 21  Total new charges associated with this invoice
# 1                                              NaN
# 5                                              NaN
# 4                                              NaN
# 3                                              NaN
# 2                                              NaN
# 0                                              NaN
#
#    fieldSchema.fields.RemittanceAddressRecipient.description  \
# 10                                                NaN
# 20                                                NaN
# 16                                                NaN
# 18                                                NaN
# 17                                                NaN
# 8                                                 NaN
# 11                                                NaN
# 9                                                 NaN
# 7                                                 NaN
# 6                                                 NaN
# 19                                                NaN
# 14                                                NaN
# 12                                                NaN
# 13                                                NaN
# 15                                                NaN
# 21         Name associated with the RemittanceAddress
# 1                                                 NaN
# 5                                                 NaN
# 4                                                 NaN
# 3                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
#
#    fieldSchema.fields.ServiceAddressRecipient.description  \
# 10                                                NaN
# 20                                                NaN
# 16                                                NaN
# 18                                                NaN
# 17                                                NaN
# 8                                                 NaN
# 11                                                NaN
# 9                                                 NaN
# 7                                                 NaN
# 6                                                 NaN
# 19                                                NaN
# 14                                                NaN
# 12                                                NaN
# 13                                                NaN
# 15                                                NaN
# 21            Name associated with the ServiceAddress
# 1                                                 NaN
# 5                                                 NaN
# 4                                                 NaN
# 3                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
#
#    fieldSchema.fields.ShippingAddressRecipient.description
# 10                                                NaN
# 20                                                NaN
# 16                                                NaN
# 18                                                NaN
# 17                                                NaN
# 8                                                 NaN
# 11                                                NaN
# 9                                                 NaN
# 7                                                 NaN
# 6                                                 NaN
# 19                                                NaN
# 14                                                NaN
# 12                                                NaN
# 13                                                NaN
# 15                                                NaN
# 21           Name associated with the ShippingAddress
# 1                                                 NaN
# 5                                                 NaN
# 4                                                 NaN
# 3                                                 NaN
# 2                                                 NaN
# 0                                                 NaN
#
# [22 rows x 304 columns]

# %% [markdown]
# ## Get analyzer details with id
#
# Remember the analyzer id when you create it. You can use the id to look up detail analyzer definitions afterwards.

# %%
result_json = client.get_analyzer_detail_by_id(CUSTOM_ANALYZER_ID)
print(json.dumps(result_json, indent=2))
# Out:
# {
#   "analyzerId": "analyzer-management-sample-b5439aca-f0a7-49ff-b504-e0750f339214",
#   "description": "Sample call recording analytics",
#   "createdAt": "2025-06-14T09:01:33Z",
#   "lastModifiedAt": "2025-06-14T09:01:33Z",
#   "baseAnalyzerId": "prebuilt-callCenter",
#   "config": {
#     "locales": [
#       "en-US"
#     ],
#     "returnDetails": true,
#     "disableContentFiltering": false
#   },
#   "fieldSchema": {
#     "fields": {
#       "Summary": {
#         "type": "string",
#         "method": "generate",
#         "description": "A one-paragraph summary"
#       },
#       "Topics": {
#         "type": "array",
#         "method": "generate",
#         "description": "Top 5 topics mentioned",
#         "items": {
#           "type": "string"
#         }
#       },
#       "Companies": {
#         "type": "array",
#         "method": "generate",
#         "description": "List of companies mentioned",
#         "items": {
#           "type": "string"
#         }
#       },
#       "People": {
#         "type": "array",
#         "method": "generate",
#         "description": "List of people mentioned",
#         "items": {
#           "type": "object",
#           "properties": {
#             "Name": {
#               "type": "string",
#               "description": "Person's name"
#             },
#             "Role": {
#               "type": "string",
#               "description": "Person's title/role"
#             }
#           }
#         }
#       },
#       "Sentiment": {
#         "type": "string",
#         "method": "classify",
#         "description": "Overall sentiment",
#         "enum": [
#           "Positive",
#           "Neutral",
#           "Negative"
#         ]
#       },
#       "Categories": {
#         "type": "array",
#         "method": "classify",
#         "description": "List of relevant categories",
#         "items": {
#           "type": "string",
#           "enum": [
#             "Agriculture",
#             "Business",
#             "Finance",
#             "Health",
#             "Insurance",
#             "Mining",
#             "Pharmaceutical",
#             "Retail",
#             "Technology",
#             "Transportation"
#           ]
#         }
#       }
#     }
#   },
#   "warnings": [],
#   "status": "ready",
#   "processingLocation": "geography",
#   "mode": "standard"
# }

# %% [markdown]
# ## Delete Analyzer
# If you don't need an analyzer anymore, delete it with its id.

# %%
client.delete_analyzer(CUSTOM_ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-management-sample-b5439aca-f0a7-49ff-b504-e0750f339214 deleted.
# <Response [204]>

# %% [markdown]
# ### Delete Analyzer by prefix

# %%
# delete all analyzers which ANALYZER_ID start with a specific prefix
prefix = "auto-labeling-model"

for analyzer in all_analyzers['value']:
    if analyzer['analyzerId'].startswith(prefix):
        print(f"Deleting analyzer: {analyzer['analyzerId']}")
        client.delete_analyzer(analyzer['analyzerId'])
        print(f"Deleted analyzer: {analyzer['analyzerId']}")
    else:
        print(f"Skipping analyzer: {analyzer['analyzerId']}")

# %% [markdown]
# ### Delete Analyzer by datetime

# %%
# delete all analyzers which ANALYZER_ID created between start and end datetime
from datetime import datetime, timezone

#2025-06-12T13:10:41Z
start_datetime_str = "2025-06-12T13:00:00Z"
end_datetime_str = "2025-06-12T14:00:00Z"

start_datetime = datetime.fromisoformat(start_datetime_str.replace("Z", "+00:00")).astimezone(timezone.utc)
end_datetime = datetime.fromisoformat(end_datetime_str.replace("Z", "+00:00")).astimezone(timezone.utc)

print(f"Start datetime: {start_datetime}")
print(f"End datetime: {end_datetime}")
# Out:
# Start datetime: 2025-06-12 13:00:00+00:00
# End datetime: 2025-06-12 14:00:00+00:00

# %%
for analyzer in all_analyzers['value']:
    deleted_analyzers = 0
    try:
        created_at = datetime.fromisoformat(analyzer['createdAt'].replace("Z", "+00:00")).astimezone(timezone.utc)
        if start_datetime <= created_at <= end_datetime:
            print(f"Deleting analyzer: {analyzer['analyzerId']}")
            client.delete_analyzer(analyzer['analyzerId'])
            print(f"Deleted analyzer: {analyzer['analyzerId']}")
            deleted_analyzers += 1
        else:
            # print(f"Skipping analyzer: {analyzer['analyzerId']}")
            print("...")
    except KeyError:
        print(f"Skipping analyzer: {analyzer['analyzerId']} (createdAt not found)")

print(f"\nTotal deleted analyzers: {deleted_analyzers}")
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# Deleting analyzer: test
# INFO:python.content_understanding_client_NEW:Analyzer test deleted.
# Deleted analyzer: test
#
# Total deleted analyzers: 1
