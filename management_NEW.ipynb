# %% [markdown]
# # Manage Analyzers in Your Resource

# %% [markdown]
# This notebook demo how to create a simple analyzer and manage its lifecycle.
#
# Source: https://github.com/Azure-Samples/azure-ai-content-understanding-python.git
# further expanded for training purposes

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The AzureContentUnderstandingClient is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# %%
load_dotenv(override=True, dotenv_path=find_dotenv())
# Out:
# True

# %%
logging.basicConfig(level=logging.INFO)

# %%
AZURE_AI_ENDPOINT = os.getenv("AZURE_CU_ENDPOINT_NEW")
AZURE_AI_API_VERSION = os.getenv("AZURE_CU_API_VERSION_NEW", "2025-05-01-preview")
print(f"Current Azure Content Understanding endpoint: {AZURE_AI_ENDPOINT}")
print(f"Current Azure Content Understanding API version: {AZURE_AI_API_VERSION}")
# Out:
# Current Azure Content Understanding endpoint: https://epaifhub6672084982.cognitiveservices.azure.com/
# Current Azure Content Understanding API version: 2025-05-01-preview

# %%
# only if necessary, add the parent directory to the path to use shared modules
# parent_dir = Path(Path.cwd()).parent
# sys.path.append(str(parent_dir))

# import the utility class AzureContentUnderstandingClient, which is a wrapper around the Azure Content Understanding REST API client
from python.content_understanding_client_NEW import AzureContentUnderstandingClient

# %%
credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS

# %%
# As an alternative to the DefaultAzureCredential, you can register an App in Entra ID and use it client secret
# from azure.identity import ClientSecretCredential

# credential = ClientSecretCredential(
#     tenant_id=os.getenv("TENANT_ID"), 
#     client_id=os.getenv("CLIENT_ID"), 
#     client_secret=os.getenv("CLIENT_SECRET") 
# )

# # Token provider compatibile
# def token_provider(scopes=None, **kwargs):
#     if scopes is None:
#         scopes = ["https://cognitiveservices.azure.com/.default"] # original value
#     token = credential.get_token(*scopes)
#     return token.token

# # scopes = ["https://cognitiveservices.azure.com/.default"] # original value
# # token = credential.get_token(*scopes)
# # print(token.token)

# %%
# consider running az login
client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/analyzer_management", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)


# This cell printout INFO level logs about the token acquisition process (e.g. AzCli vs ClientSecretCredential)
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.identity._internal.get_token_mixin:ClientSecretCredential.get_token succeeded

# %% [markdown]
# ## Create a simple analyzer
# We first create an analyzer from a template to extract invoice fields.

# %%
import uuid

ANALYZER_TEMPLATE = "analyzer_templates_NEw/call_recording_analytics.json"
CUSTOM_ANALYZER_ID = "analyzer-management-sample-" + str(uuid.uuid4())

response = client.begin_create_analyzer(CUSTOM_ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE)
result = client.poll_result(response)

print(json.dumps(result, indent=2))
# Out:
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-management-sample-cc0e7b5a-3688-4858-b21e-04b322a59ee4 create request accepted.
# INFO:python.content_understanding_client_NEW:Request result is ready after 0.00 seconds.
# {
#   "id": "43b55586-f500-4a37-9c86-3a75ec5164e2",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "analyzer-management-sample-cc0e7b5a-3688-4858-b21e-04b322a59ee4",
#     "description": "Sample call recording analytics",
#     "createdAt": "2025-06-25T13:39:06Z",
#     "lastModifiedAt": "2025-06-25T13:39:06Z",
#     "baseAnalyzerId": "prebuilt-callCenter",
#     "config": {
#       "locales": [
#         "en-US"
#       ],
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "method": "generate",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "method": "generate",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "method": "generate",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# }

# %% [markdown]
# ## List all analyzers created in your resource

# %% [markdown]
# After the analyzer is successfully created, we can use it to analyze our input files.

# %%
all_analyzers = client.get_all_analyzers()
print(f"Number of analyzers in your resource: {len(all_analyzers['value'])}")
# print(f"The first 3 analyzer details: {json.dumps(all_analyzers['value'][:3], indent=2)}")
# print(f"The last analyzer details: {json.dumps(all_analyzers['value'][:-1], indent=2)}")
# Out:
# Number of analyzers in your resource: 6
# The last analyzer details: [
#   {
#     "analyzerId": "prebuilt-callCenter",
#     "description": "Analyze call center conversations to extract transcripts, summaries, sentiment, and more.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "PostCallAnalytics",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary"
#         },
#         "Topics": {
#           "type": "array",
#           "description": "Top 5 topics mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "Companies": {
#           "type": "array",
#           "description": "List of companies mentioned",
#           "items": {
#             "type": "string"
#           }
#         },
#         "People": {
#           "type": "array",
#           "description": "List of people mentioned",
#           "items": {
#             "type": "object",
#             "properties": {
#               "Name": {
#                 "type": "string",
#                 "description": "Person's name"
#               },
#               "Role": {
#                 "type": "string",
#                 "description": "Person's title/role"
#               }
#             }
#           }
#         },
#         "Sentiment": {
#           "type": "string",
#           "method": "classify",
#           "description": "Overall sentiment",
#           "enum": [
#             "Positive",
#             "Neutral",
#             "Negative"
#           ]
#         },
#         "Categories": {
#           "type": "array",
#           "method": "classify",
#           "description": "List of relevant categories",
#           "items": {
#             "type": "string",
#             "enum": [
#               "Agriculture",
#               "Business",
#               "Finance",
#               "Health",
#               "Insurance",
#               "Mining",
#               "Pharmaceutical",
#               "Retail",
#               "Technology",
#               "Transportation"
#             ]
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-audioAnalyzer",
#     "description": "Transcribe conversations and extract summaries.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "AudioAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph summary of the conversation."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-documentAnalyzer",
#     "description": "Extract various content and layout elements such as words, paragraphs, and tables from documents.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "tableFormat": "html",
#       "estimateFieldSourceAndConfidence": false
#     },
#     "fieldSchema": {
#       "name": "DocumentAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph description of the document."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-imageAnalyzer",
#     "description": "Analyze images to generate descriptions.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": false,
#       "disableContentFiltering": false
#     },
#     "fieldSchema": {
#       "name": "ImageAnalysis",
#       "fields": {
#         "Summary": {
#           "type": "string",
#           "description": "A one-paragraph description of the image."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   },
#   {
#     "analyzerId": "prebuilt-invoice",
#     "description": "Extract invoice document fields.",
#     "createdAt": "2025-05-01T00:00:00Z",
#     "config": {
#       "returnDetails": true,
#       "enableOcr": true,
#       "enableLayout": true,
#       "enableFormula": false,
#       "disableContentFiltering": false,
#       "estimateFieldSourceAndConfidence": true
#     },
#     "fieldSchema": {
#       "name": "InvoiceAnalysis",
#       "fields": {
#         "CustomerName": {
#           "type": "string",
#           "method": "extract",
#           "description": "The full name of the customer, including the primary company name and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing."
#         },
#         "InvoiceDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "CustomerId": {
#           "type": "string",
#           "method": "extract"
#         },
#         "PurchaseOrder": {
#           "type": "string",
#           "method": "extract"
#         },
#         "InvoiceId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The unique identifier of the invoice, often named 'Invoice Number'"
#         },
#         "DueDate": {
#           "type": "date",
#           "method": "extract"
#         },
#         "VendorName": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddress": {
#           "type": "string",
#           "method": "extract"
#         },
#         "CustomerAddressRecipient": {
#           "type": "string",
#           "method": "extract",
#           "description": "The recepient of customer addresss, including the recepient and associated identifiers such as C/O (Care Of), BU# (Business Unit number), ATTN: (Attention to), department names, or other relevant details if existing. Ensure that all parts related to the customer\u2019s recepient identification are included to provide complete context."
#         },
#         "BillingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit billing address of the customer."
#         },
#         "BillingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ShippingAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit shipping address of the customer."
#         },
#         "ShippingAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "SubTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalDiscount": {
#           "type": "number",
#           "method": "extract"
#         },
#         "TotalTax": {
#           "type": "number",
#           "method": "extract"
#         },
#         "InvoiceTotal": {
#           "type": "number",
#           "method": "extract"
#         },
#         "AmountDue": {
#           "type": "number",
#           "method": "extract"
#         },
#         "PreviousUnpaidBalance": {
#           "type": "number",
#           "method": "extract",
#           "description": "Explicit previously unpaid balance. Please make sure it is **unpaid**, not the total amount of the previous invoice."
#         },
#         "RemittanceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address to which the payment or remittance should be sent."
#         },
#         "RemittanceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "ServiceAddress": {
#           "type": "string",
#           "method": "extract",
#           "description": "The explicit address where the service was provided."
#         },
#         "ServiceAddressRecipient": {
#           "type": "string",
#           "method": "extract"
#         },
#         "VendorTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the vendor"
#         },
#         "CustomerTaxId": {
#           "type": "string",
#           "method": "extract",
#           "description": "The government ID number associated with the customer"
#         },
#         "PaymentTerm": {
#           "type": "string",
#           "method": "extract"
#         },
#         "TaxDetails": {
#           "type": "array",
#           "method": "extract",
#           "description": "The tax details of the invoice.",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "Amount": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Rate": {
#                 "type": "number",
#                 "method": "extract"
#               }
#             }
#           }
#         },
#         "Items": {
#           "type": "array",
#           "method": "extract",
#           "items": {
#             "type": "object",
#             "method": "extract",
#             "properties": {
#               "TotalPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The total amount of the line item."
#               },
#               "Date": {
#                 "type": "date",
#                 "method": "extract"
#               },
#               "Description": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "Quantity": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "ProductCode": {
#                 "type": "string",
#                 "method": "extract",
#                 "description": "Product code, product number, or SKU associated with the specific line item"
#               },
#               "TaxAmount": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The tax amount of the line item."
#               },
#               "TaxRate": {
#                 "type": "number",
#                 "method": "extract"
#               },
#               "Unit": {
#                 "type": "string",
#                 "method": "extract"
#               },
#               "UnitPrice": {
#                 "type": "number",
#                 "method": "extract",
#                 "description": "The net or gross price of one unit of the item"
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# ]

# %%
import pandas as pd
df_analyzers = pd.json_normalize(all_analyzers['value'])
df_analyzers_sorted = df_analyzers.sort_values(by='createdAt', ascending=False)
df_analyzers_sorted
# Out:
#                   analyzerId  \
# 0        prebuilt-callCenter
# 1     prebuilt-audioAnalyzer
# 2  prebuilt-documentAnalyzer
# 3     prebuilt-imageAnalyzer
# 4           prebuilt-invoice
# 5     prebuilt-videoAnalyzer
#
#                                          description             createdAt  \
# 0  Analyze call center conversations to extract t...  2025-05-01T00:00:00Z
# 1    Transcribe conversations and extract summaries.  2025-05-01T00:00:00Z
# 2  Extract various content and layout elements su...  2025-05-01T00:00:00Z
# 3           Analyze images to generate descriptions.  2025-05-01T00:00:00Z
# 4                   Extract invoice document fields.  2025-05-01T00:00:00Z
# 5  Analyze videos to extract transcript and descr...  2025-05-01T00:00:00Z
#
#   warnings status processingLocation      mode  config.returnDetails  \
# 0       []  ready          geography  standard                  True
# 1       []  ready          geography  standard                  True
# 2       []  ready          geography  standard                  True
# 3       []  ready          geography  standard                  True
# 4       []  ready          geography  standard                  True
# 5       []  ready          geography  standard                  True
#
#    config.disableContentFiltering   fieldSchema.name  ...  \
# 0                           False  PostCallAnalytics  ...
# 1                           False      AudioAnalysis  ...
# 2                           False   DocumentAnalysis  ...
# 3                           False      ImageAnalysis  ...
# 4                           False    InvoiceAnalysis  ...
# 5                           False      VideoAnalysis  ...
#
#   fieldSchema.fields.Items.items.properties.UnitPrice.description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4     The net or gross price of one unit of the item
# 5                                                NaN
#
#   config.enableFace config.segmentationMode config.disableFaceBlurring  \
# 0               NaN                     NaN                        NaN
# 1               NaN                     NaN                        NaN
# 2               NaN                     NaN                        NaN
# 3               NaN                     NaN                        NaN
# 4               NaN                     NaN                        NaN
# 5             False                    auto                      False
#
#   fieldSchema.fields.Segments.type fieldSchema.fields.Segments.items.type  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# 5                            array                                 object
#
#   fieldSchema.fields.Segments.items.properties.SegmentId.type  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                             string
#
#   fieldSchema.fields.Segments.items.properties.StartTimeMs.type  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                            integer
#
#   fieldSchema.fields.Segments.items.properties.EndTimeMs.type  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                            integer
#
#   fieldSchema.fields.Segments.items.properties.Description.type
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                             string
#
# [6 rows x 149 columns]

# %% [markdown]
# ## Get analyzer details with id
#
# Remember the analyzer id when you create it. You can use the id to look up detail analyzer definitions afterwards.

# %%
result_json = client.get_analyzer_detail_by_id(CUSTOM_ANALYZER_ID)
print(json.dumps(result_json, indent=2))
# Out:
# {
#   "analyzerId": "analyzer-management-sample-cc0e7b5a-3688-4858-b21e-04b322a59ee4",
#   "description": "Sample call recording analytics",
#   "createdAt": "2025-06-25T13:39:06Z",
#   "lastModifiedAt": "2025-06-25T13:39:06Z",
#   "baseAnalyzerId": "prebuilt-callCenter",
#   "config": {
#     "locales": [
#       "en-US"
#     ],
#     "returnDetails": true,
#     "disableContentFiltering": false
#   },
#   "fieldSchema": {
#     "fields": {
#       "Summary": {
#         "type": "string",
#         "method": "generate",
#         "description": "A one-paragraph summary"
#       },
#       "Topics": {
#         "type": "array",
#         "method": "generate",
#         "description": "Top 5 topics mentioned",
#         "items": {
#           "type": "string"
#         }
#       },
#       "Companies": {
#         "type": "array",
#         "method": "generate",
#         "description": "List of companies mentioned",
#         "items": {
#           "type": "string"
#         }
#       },
#       "People": {
#         "type": "array",
#         "method": "generate",
#         "description": "List of people mentioned",
#         "items": {
#           "type": "object",
#           "properties": {
#             "Name": {
#               "type": "string",
#               "description": "Person's name"
#             },
#             "Role": {
#               "type": "string",
#               "description": "Person's title/role"
#             }
#           }
#         }
#       },
#       "Sentiment": {
#         "type": "string",
#         "method": "classify",
#         "description": "Overall sentiment",
#         "enum": [
#           "Positive",
#           "Neutral",
#           "Negative"
#         ]
#       },
#       "Categories": {
#         "type": "array",
#         "method": "classify",
#         "description": "List of relevant categories",
#         "items": {
#           "type": "string",
#           "enum": [
#             "Agriculture",
#             "Business",
#             "Finance",
#             "Health",
#             "Insurance",
#             "Mining",
#             "Pharmaceutical",
#             "Retail",
#             "Technology",
#             "Transportation"
#           ]
#         }
#       }
#     }
#   },
#   "warnings": [],
#   "status": "ready",
#   "processingLocation": "geography",
#   "mode": "standard"
# }

# %% [markdown]
# ## Delete Analyzer
# If you don't need an analyzer anymore, delete it with its id.

# %%
client.delete_analyzer(CUSTOM_ANALYZER_ID)
# Out:
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-management-sample-cc0e7b5a-3688-4858-b21e-04b322a59ee4 deleted.
# <Response [204]>

# %% [markdown]
# ### Delete Analyzer by prefix

# %%
# delete all analyzers which ANALYZER_ID start with a specific prefix
prefix = "auto-labeling-model"

for analyzer in all_analyzers['value']:
    if analyzer['analyzerId'].startswith(prefix):
        print(f"Deleting analyzer: {analyzer['analyzerId']}")
        client.delete_analyzer(analyzer['analyzerId'])
        print(f"Deleted analyzer: {analyzer['analyzerId']}")
    else:
        print(f"Skipping analyzer: {analyzer['analyzerId']}")
# Out:
# Skipping analyzer: prebuilt-callCenter
# Skipping analyzer: prebuilt-audioAnalyzer
# Skipping analyzer: prebuilt-documentAnalyzer
# Skipping analyzer: prebuilt-imageAnalyzer
# Skipping analyzer: prebuilt-invoice
# Skipping analyzer: prebuilt-videoAnalyzer
# Skipping analyzer: analyzer-001-build-demo-invoice
# Skipping analyzer: analyzer-002-my-demo-invoice
# Skipping analyzer: analyzer-invoice-sample-2025-new
# Skipping analyzer: analyzer-invoice-sample-2025
# Skipping analyzer: analyzer-prebuilt-invoice-sample-2025
# Deleting analyzer: auto-labeling-model-1749917375361-848
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1749917375361-848 deleted.
# Deleted analyzer: auto-labeling-model-1749917375361-848
# Deleting analyzer: auto-labeling-model-1750076115042-916
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1750076115042-916 deleted.
# Deleted analyzer: auto-labeling-model-1750076115042-916
# Deleting analyzer: auto-labeling-model-1750173777774-800
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1750173777774-800 deleted.
# Deleted analyzer: auto-labeling-model-1750173777774-800
# Deleting analyzer: auto-labeling-model-1750174781276-292
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1750174781276-292 deleted.
# Deleted analyzer: auto-labeling-model-1750174781276-292
# Deleting analyzer: auto-labeling-model-1750191265147-23
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1750191265147-23 deleted.
# Deleted analyzer: auto-labeling-model-1750191265147-23
# Deleting analyzer: auto-labeling-model-1750849347196-970
# INFO:python.content_understanding_client_NEW:Analyzer auto-labeling-model-1750849347196-970 deleted.
# Deleted analyzer: auto-labeling-model-1750849347196-970
# Skipping analyzer: business-card-analyzer-lab
# Skipping analyzer: business_card_analyser_procode
# Skipping analyzer: content-understanding-search-sample-7e45ddc7-1765-495b-818d-dc76f1883196
# Skipping analyzer: cu-analyzer-invoice-contract-verification
# Skipping analyzer: cu-business-card-analyzer-ui
# Skipping analyzer: cu-chart-analyzer-expert
# Skipping analyzer: cu-chart-analyzer
# Skipping analyzer: cu-chart-understanding-analyzer
# Skipping analyzer: cu-mixed-invoice-analyzer
# Skipping analyzer: cu-step-by-step-analyzer
# Skipping analyzer: invoice-analyzer
# Skipping analyzer: invoice-po-matching-analyzer
# Skipping analyzer: invoice-po-wreference-files
# Skipping analyzer: invoice-vs-purchase-order-analyzer
# Skipping analyzer: multiple-file-analyzer
# Skipping analyzer: my-video-step-analyzer
# Skipping analyzer: po-simple-analyzer
# Skipping analyzer: singlefile-invoice-analyzer-v00

# %% [markdown]
# ### Delete Analyzer by datetime

# %%
# delete all analyzers which ANALYZER_ID created between start and end datetime
from datetime import datetime, timezone

#2025-06-12T13:10:41Z
start_datetime_str = "2025-06-01T13:00:00Z"
end_datetime_str = "2025-06-30T14:00:00Z"

start_datetime = datetime.fromisoformat(start_datetime_str.replace("Z", "+00:00")).astimezone(timezone.utc)
end_datetime = datetime.fromisoformat(end_datetime_str.replace("Z", "+00:00")).astimezone(timezone.utc)

print(f"Start datetime: {start_datetime}")
print(f"End datetime: {end_datetime}")
# Out:
# Start datetime: 2025-06-01 13:00:00+00:00
# End datetime: 2025-06-30 14:00:00+00:00

# %%
deleted_analyzers = 0
for analyzer in all_analyzers['value']:
    try:
        created_at = datetime.fromisoformat(analyzer['createdAt'].replace("Z", "+00:00")).astimezone(timezone.utc)
        if start_datetime <= created_at <= end_datetime:
            print(f"Deleting analyzer: {analyzer['analyzerId']}")
            client.delete_analyzer(analyzer['analyzerId'])
            print(f"Deleted analyzer: {analyzer['analyzerId']}")
            deleted_analyzers += 1
        else:
            # print(f"Skipping analyzer: {analyzer['analyzerId']}")
            print("...")
    except KeyError:
        print(f"Skipping analyzer: {analyzer['analyzerId']} (createdAt not found)")

print(f"\nTotal deleted analyzers: {deleted_analyzers}")
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# Deleting analyzer: analyzer-001-build-demo-invoice
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-001-build-demo-invoice deleted.
# Deleted analyzer: analyzer-001-build-demo-invoice
# Deleting analyzer: analyzer-002-my-demo-invoice
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-002-my-demo-invoice deleted.
# Deleted analyzer: analyzer-002-my-demo-invoice
# Deleting analyzer: analyzer-invoice-sample-2025-new
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-invoice-sample-2025-new deleted.
# Deleted analyzer: analyzer-invoice-sample-2025-new
# Deleting analyzer: analyzer-invoice-sample-2025
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-invoice-sample-2025 deleted.
# Deleted analyzer: analyzer-invoice-sample-2025
# Deleting analyzer: analyzer-prebuilt-invoice-sample-2025
# INFO:python.content_understanding_client_NEW:Analyzer analyzer-prebuilt-invoice-sample-2025 deleted.
# Deleted analyzer: analyzer-prebuilt-invoice-sample-2025
# Deleting analyzer: business-card-analyzer-lab
# INFO:python.content_understanding_client_NEW:Analyzer business-card-analyzer-lab deleted.
# Deleted analyzer: business-card-analyzer-lab
# Deleting analyzer: business_card_analyser_procode
# INFO:python.content_understanding_client_NEW:Analyzer business_card_analyser_procode deleted.
# Deleted analyzer: business_card_analyser_procode
# Deleting analyzer: content-understanding-search-sample-7e45ddc7-1765-495b-818d-dc76f1883196
# INFO:python.content_understanding_client_NEW:Analyzer content-understanding-search-sample-7e45ddc7-1765-495b-818d-dc76f1883196 deleted.
# Deleted analyzer: content-understanding-search-sample-7e45ddc7-1765-495b-818d-dc76f1883196
# Deleting analyzer: cu-analyzer-invoice-contract-verification
# INFO:python.content_understanding_client_NEW:Analyzer cu-analyzer-invoice-contract-verification deleted.
# Deleted analyzer: cu-analyzer-invoice-contract-verification
# Deleting analyzer: cu-business-card-analyzer-ui
# INFO:python.content_understanding_client_NEW:Analyzer cu-business-card-analyzer-ui deleted.
# Deleted analyzer: cu-business-card-analyzer-ui
# Deleting analyzer: cu-chart-analyzer-expert
# INFO:python.content_understanding_client_NEW:Analyzer cu-chart-analyzer-expert deleted.
# Deleted analyzer: cu-chart-analyzer-expert
# Deleting analyzer: cu-chart-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer cu-chart-analyzer deleted.
# Deleted analyzer: cu-chart-analyzer
# Deleting analyzer: cu-chart-understanding-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer cu-chart-understanding-analyzer deleted.
# Deleted analyzer: cu-chart-understanding-analyzer
# Deleting analyzer: cu-mixed-invoice-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer cu-mixed-invoice-analyzer deleted.
# Deleted analyzer: cu-mixed-invoice-analyzer
# Deleting analyzer: cu-step-by-step-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer cu-step-by-step-analyzer deleted.
# Deleted analyzer: cu-step-by-step-analyzer
# Deleting analyzer: invoice-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer invoice-analyzer deleted.
# Deleted analyzer: invoice-analyzer
# Deleting analyzer: invoice-po-matching-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer invoice-po-matching-analyzer deleted.
# Deleted analyzer: invoice-po-matching-analyzer
# Deleting analyzer: invoice-po-wreference-files
# INFO:python.content_understanding_client_NEW:Analyzer invoice-po-wreference-files deleted.
# Deleted analyzer: invoice-po-wreference-files
# Deleting analyzer: invoice-vs-purchase-order-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer invoice-vs-purchase-order-analyzer deleted.
# Deleted analyzer: invoice-vs-purchase-order-analyzer
# Deleting analyzer: multiple-file-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer multiple-file-analyzer deleted.
# Deleted analyzer: multiple-file-analyzer
# Deleting analyzer: my-video-step-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer my-video-step-analyzer deleted.
# Deleted analyzer: my-video-step-analyzer
# Deleting analyzer: po-simple-analyzer
# INFO:python.content_understanding_client_NEW:Analyzer po-simple-analyzer deleted.
# Deleted analyzer: po-simple-analyzer
# Deleting analyzer: singlefile-invoice-analyzer-v00
# INFO:python.content_understanding_client_NEW:Analyzer singlefile-invoice-analyzer-v00 deleted.
# Deleted analyzer: singlefile-invoice-analyzer-v00
#
# Total deleted analyzers: 1
